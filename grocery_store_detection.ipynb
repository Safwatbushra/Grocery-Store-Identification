# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qzESa6WSfT2KKjerFYTU")
project = rf.workspace("yolo-9co33").project("grocery-store-hr9us")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 23.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 83.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 111.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Grocery-Store-1 in yolov8:: 100%|██████████| 3312/3312 [00:00<00:00, 7343.25it/s]

# %%
import os
import glob

# See what got downloaded
print(os.listdir('/content'))

# Find yaml file
yaml_files = glob.glob('/content/**/*.yaml', recursive=True)
print("\nYAML file found at:")
print(yaml_files)
# Out:
# ['.config', 'Grocery-Store-1', 'sample_data']
#
# YAML file found at:
# ['/content/Grocery-Store-1/data.yaml']

# %%
# !pip install ultralytics

from ultralytics import YOLO

# Load pretrained YOLOv8 small model (transfer learning from COCO)
model = YOLO("yolov8s.pt")

# Train on your Grocery Store dataset
model.train(
    data="/content/Grocery-Store-1/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    name="grocery_detection"
)

print("Training Completed")
# Out:
# ...
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/grocery_detection/weights/best.pt')
